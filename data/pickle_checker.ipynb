# %%
#Python Library for Dataframe usage
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Serializing to a file
import _pickle as pickle

# %%
pickle_in = open("./pandas/flavorDB_pandas.pickle","rb")

#Getting the dictionary from the pickle
flavor_pickle = pickle.load(pickle_in)

# %%
flavor_pickle.head()
# Out:
#                         _id       ingredient        catgeory  \
# 0  5ca27b8f13218a1eabac63d6              Egg  Animal Product
# 1  5ca27b9113218a1eabac63d7  Bakery Products          Bakery
# 2  5ca27b9213218a1eabac63d8            Bread          Bakery
# 3  5ca27b9313218a1eabac63d9        Rye Bread          Bakery
# 4  5ca27b9413218a1eabac63da    Wheaten Bread          Bakery
#
#                                            molecules  \
# 0  [L-arginine, 3-Methylindole, 2,5-Dimethylpyraz...
# 1  [2,3-Dimethylpyrazine, 2,5-Dimethylpyrazine, 2...
# 2  [coumarin, Methyl Benzoate, 3-Hexanone, Gerani...
# 3  [2-Methylbutyl Acetate, 3-methylthiopropanol, ...
# 4  [Difurfuryl ether, 2-Undecanone, Octyl acetate...
#
#                                         molecule_IDs  \
# 0  [6322, 6736, 31252, 7909, 7284, 7501, 9609, 12...
# 1          [22201, 31252, 26331, 27457, 7976, 26808]
# 2  [323, 7150, 11509, 637566, 439341, 33931, 9261...
# 3  [12209, 10448, 5372954, 8468, 643731, 7344, 18...
# ...

# %%
pickle_in = open("./pandas/recipe_puppy_pandas.pickle","rb")

#Getting the dictionary from the pickle
puppy_pickle = pickle.load(pickle_in)

# %%
puppy_pickle.head()
# Out:
#                         _id  \
# 0  5caa762213218a112b0b979f
# 1  5caa762213218a112b0b97a0
# 2  5caa762213218a112b0b97a1
# 3  5caa762213218a112b0b97a2
# 4  5caa762213218a112b0b97a3
#
#                                   recipe_ingredients  \
# 0  [dashi, egg, egg noodles, mushroom, salt, seas...
# 1                                       [egg, water]
# 2  [black pepper, celery, cucumber, curry powder,...
# 3  [baking powder, butter, egg, green onion, rame...
# 4           [bacon, black pepper, cheese, egg, salt]
#
#                                          recipe_link  \
# 0  http://www.grouprecipes.com/31653/egg-noodles-...
# 1  http://www.recipezaar.com/Egg-Peeling-for-Egg-...
# 2  http://www.recipezaar.com/Curried-Egg-Salad-on...
# 3  http://www.recipezaar.com/Ramen-Noodle-Egg-Foo...
# 4  http://www.recipezaar.com/Bacon-and-Egg-Cups-1...
#
#                                          recipe_name searched_ingredient
# ...
