# %%
#Python Libraries for Mongos Database
import pymongo
from pymongo import MongoClient

#Serializing to a file
import _pickle as pickle

# %%
#Python Library for Dataframe usage
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
#accessing mongoDB
client = MongoClient()
database = client['food_map']   # Database name (to connect to)
collections = database['flavor_molecules']

# %%
#Getting the dataset from MongoDB into Pandas
flavorDB_pandas = pd.DataFrame(list(collections.find()))
flavorDB_pandas = flavorDB_pandas.rename(index=str, columns={"catgeory": "category"})

# %%
#Making each list into a set
flavorDB_pandas["ingredient"] = flavorDB_pandas["ingredient"].apply(lambda row: row.lower())
flavorDB_pandas["set_molecules"] = flavorDB_pandas["molecules"].apply(lambda row: set(row))
flavorDB_pandas["set_molecules_ID"] = flavorDB_pandas["molecule_IDs"].apply(lambda row: set(row))
flavorDB_pandas["molecule_quantity"] = flavorDB_pandas["molecule_IDs"].apply(lambda row: len(row))

# %% [markdown]
# # Before Cleaning

# %%
flavorDB_pandas.head()
# Out:
#                         _id        category  \
# 0  5ca27b8f13218a1eabac63d6  Animal Product
# 1  5ca27b9113218a1eabac63d7          Bakery
# 2  5ca27b9213218a1eabac63d8          Bakery
# 3  5ca27b9313218a1eabac63d9          Bakery
# 4  5ca27b9413218a1eabac63da          Bakery
#
#                                  flavor_of_molecules       ingredient  \
# 0  [[faint], [very strong,  mothball,  animal,  f...              egg
# 1  [[butter,  caramel,  nut,  peanut butter,  mea...  bakery products
# 2  [[sweet,  new mown hay,  green,  tonka,  bitte...            bread
# 3  [[overripe fruit,  banana,  fruit,  sweet,  pe...        rye bread
# 4  [[nutty,  coffee], [orange,  waxy,  fresh,  fa...    wheaten bread
#
#                                         molecule_IDs  \
# 0  [6322, 6736, 31252, 7909, 7284, 7501, 9609, 12...
# 1          [22201, 31252, 26331, 27457, 7976, 26808]
# 2  [323, 7150, 11509, 637566, 439341, 33931, 9261...
# 3  [12209, 10448, 5372954, 8468, 643731, 7344, 18...
# 4  [263034, 8163, 8164, 12170, 228583, 9589, 6375...
#
#                                            molecules  \
# 0  [L-arginine, 3-Methylindole, 2,5-Dimethylpyraz...
# 1  [2,3-Dimethylpyrazine, 2,5-Dimethylpyrazine, 2...
# 2  [coumarin, Methyl Benzoate, 3-Hexanone, Gerani...
# 3  [2-Methylbutyl Acetate, 3-methylthiopropanol, ...
# 4  [Difurfuryl ether, 2-Undecanone, Octyl acetate...
#
#                                        set_molecules  \
# 0  {octanoic acid, 2-Pentanone, indole, 4-Methylt...
# 1  {2-Ethyl-3-Methylpyrazine, 2,3-Dimethylpyrazin...
# 2  {2-Acetylpyridine, cis-3-Hexenal, hydrogen cya...
# 3  {Violet leaf aldehyde, Maltol, 2-Methylbutyl A...
# 4  {2-Ethylbutyric Acid, methylglyoxal, 2-Pentano...
#
#                                     set_molecules_ID  molecule_quantity
# 0  {8027, 6322, 798, 342, 1068, 878, 5311110, 957...                 55
# 1          {26331, 7976, 31252, 22201, 27457, 26808}                  6
# 2  {637566, 8723, 26447, 14286, 13144, 527, 63754...                129
# 3  {999, 25915, 72, 8468, 32065, 7344, 7997, 7824...                 30
# 4  {8027, 19310, 31251, 22386, 14286, 6915, 26334...                 30

# %%
print("total number of ingredients: ", len(flavorDB_pandas["ingredient"]))
# Out:
# total number of ingredients:  935

# %%
flavorDB_pandas["category"].unique()
# Out:
# array(['Animal Product', 'Bakery', 'Beverage', 'Beverage Alcoholic',
#        'Beverage Caffeinated', 'Cereal', 'Maize', 'Dairy',
#        'Essential Oil', 'Berry', 'Seafood', 'Fish', 'Flower', 'Fruit',
#        'Fruit-Berry', 'Fruit Citrus', 'Fruit Essence', 'Fungus', 'Herb',
#        'Meat', 'Dish', 'Nut', 'Seed', 'Legume', 'Plant Derivative',
#        'Plant', 'Spice', 'Vegetable', 'Cabbage', 'Vegetable Root',
#        'Vegetable Fruit', 'Gourd', 'Vegetable Stem', 'Vegetable Tuber',
#        'Additive'], dtype=object)

# %%
for category in flavorDB_pandas["category"] .unique():
    print(category)
    category_list = flavorDB_pandas[flavorDB_pandas["category"] == category]["ingredient"]
    print(category_list)
# Out:
# Animal Product
# 0    egg
# Name: ingredient, dtype: object
# Bakery
# 1          bakery products
# 2                    bread
# 3                rye bread
# 4            wheaten bread
# 5              white bread
# 6         wholewheat bread
# 372           fried potato
# 475                  pasta
# 476                biscuit
# 774            marshmallow
# 785               meringue
# 812            potato chip
# 813          tortilla chip
# 814              corn chip
# 863           phyllo dough
# 865              pie crust
# 883             pita bread
# 884               focaccia
# 885                  bagel
# 886    other bread product
# 887             piki bread
# 888           french toast
# 889              oat bread
# 890           potato bread
# 893       multigrain bread
# 894             rice bread
# 895              pan dulce
# 896           raisin bread
# 897         wonton wrapper
# 904       chocolate mousse
# 915                  fudge
# 916              candy bar
# Name: ingredient, dtype: object
# Beverage
# 7                   wort
# 789        hot chocolate
# 800         energy drink
# 815         hibiscus tea
# 828             soy milk
# 830             cocktail
# 843    nutritional drink
# 851          fruit juice
# 899      greenthread tea
# 900      vegetable juice
# 901             horchata
# 902           soft drink
# 903            milkshake
# Name: ingredient, dtype: object
# Beverage Alcoholic
# 8                        arrack
# 9                          beer
# 10                   bantu beer
# 11                       brandy
# 12                 anise brandy
# 13                 apple brandy
# 14              armagnac brandy
# 15            blackberry brandy
# 16                cherry brandy
# 17                cognac brandy
# 18                papaya brandy
# 19                  pear brandy
# 20                  plum brandy
# 21             raspberry brandy
# 22             weinbrand brandy
# 23                          gin
# 24                          rum
# 25                       whisky
# 26               bourbon whisky
# 27              canadian whisky
# 28               finnish whisky
# 29              japanese whisky
# 30                  malt whisky
# 31                scotch whisky
# 32                         wine
# 33                bilberry wine
# 34              botrytized wine
# 35                    champagne
# 36                        cider
# 37                    plum wine
# 38                    port wine
# 39                     red wine
# 40                    rose wine
# 41                         sake
# 42                       sherry
# 43               sparkling wine
# 44              strawberry wine
# 45                   white wine
# 478                      spirit
# 479    beverage alcolohic other
# 744                  berry wine
# 745                       vodka
# 747                    vermouth
# 748                madeira wine
# Name: ingredient, dtype: object
# Beverage Caffeinated
# 46             coffee
# 47               mate
# 48          black tea
# 49          green tea
# 50         roibos tea
# 414    arabica coffee
# 833      coffee mocha
# Name: ingredient, dtype: object
# Cereal
# 51                barley
# 52            crispbread
# 53                  malt
# 54                  oats
# 55                  rice
# 318                  rye
# 401         basmati rice
# 418    tartary buckwheat
# 442              sorghum
# 446                wheat
# 463             red rice
# 464     annual wild rice
# 466           hard wheat
# 467            triticale
# 474     breakfast cereal
# 477            sourdough
# 605               quinoa
# 638                spelt
# 658            wild rice
# 682       oriental wheat
# 832               bulgur
# 835             semolina
# 881                flour
# Name: ingredient, dtype: object
# Maize
# 56           corn
# 57       corn oil
# 58        popcorn
# 59      sweetcorn
# 891     cornbread
# 892    corn grits
# Name: ingredient, dtype: object
# Dairy
# 60                   butter
# 61               buttermilk
# 62                   cheese
# 63              blue cheese
# 64         camembert cheese
# 65           cheddar cheese
# 66             comte cheese
# 67           cottage cheese
# 68             cream cheese
# 69           domiati cheese
# 70          emmental cheese
# 71              feta cheese
# 72              goat cheese
# 73           gruyere cheese
# 74        mozzarella cheese
# 75           munster cheese
# 76            other cheeses
# 77          parmesan cheese
# 78         provolone cheese
# 79            romano cheese
# 80         roquefort cheese
# 81           russian cheese
# 82             sheep cheese
# 83             swiss cheese
# 84            tilsit cheese
# 85           dairy products
# 86                     ghee
# 87                     milk
# 88                 milk fat
# 89                goat milk
# 90              milk powder
# 91               sheep milk
# 92             skimmed milk
# 93                   yogurt
# 399                  paneer
# 402          ricotta cheese
# 753                    ymer
# 762                   cream
# 770                    whey
# 778              milk human
# 790                   kefir
# 791    other fermented milk
# 809           sweet custard
# 818                  junket
# 880         evaporated milk
# 917          condensed milk
# 929       mozzarella cheese
# 933          dulce de leche
# Name: ingredient, dtype: object
# Essential Oil
# 94                    achilleas
# 95                         arar
# 96                        buchu
# 97                      cajeput
# 98                      camphor
# 99                   cascarilla
# 100                       cedar
# 101                   chamomile
# 102                  citronella
# 103             citrus peel oil
# 104                  eucalyptus
# 105                         fir
# 106                    geranium
# 107         grapefruit peel oil
# 108                       grass
# 109                    hops oil
# 110                    hyacinth
# 111                  hyssop oil
# 112                 lemon grass
# 113              lemon peel oil
# 114               lime peel oil
# 115                      lovage
# 116    mandarin orange peel oil
# 117                  mastic gum
# 118                  mentha oil
# 119                       myrrh
# 120                  neroli oil
# 121                  orange oil
# 122                       orris
# 123                  clary sage
# 124                    red sage
# 125                spanish sage
# 126                  sandalwood
# 128                 sweet grass
# 129                    valerian
# 130                      wattle
# 131                      yarrow
# 132                 ylang-ylang
# 378                  canola oil
# 387                       kenaf
# 388                       lotus
# 390                       kewda
# Name: ingredient, dtype: object
# Berry
# 127          sea buckthorns
# 218                   berry
# 219                bilberry
# 220              blackberry
# 221               blueberry
# 222                  cherry
# 223           bitter cherry
# 224             sour cherry
# 225             wild cherry
# 226              cloudberry
# 227               cranberry
# 228              gooseberry
# 229             lingonberry
# 230              loganberry
# 231               raspberry
# 232              strawberry
# 233          strawberry jam
# 416         black crowberry
# 419       black huckleberry
# 428                mulberry
# 429          black mulberry
# 435           red raspberry
# 436         black raspberry
# 440           cherry tomato
# 441              rowanberry
# 447            sparkleberry
# 454                bayberry
# 455     elliott's blueberry
# 456        canada blueberry
# 457               deerberry
# 470              jostaberry
# 482                 acerola
# 533             squashberry
# 555            groundcherry
# 589             ohelo berry
# 600                 pitanga
# 621             salmonberry
# 649    mexican groundcherry
# 686             boysenberry
# 923        chinese bayberry
# 926         saskatoon berry
# 927          nanking cherry
# Name: ingredient, dtype: object
# Seafood
# 133                           clam
# 134                           crab
# 135                       crayfish
# 136                           kelp
# 137                          krill
# 138                        lobster
# 139                        mollusc
# 140                         oyster
# 141                          prawn
# 142                        scallop
# 143                      shellfish
# 144                         shrimp
# 145                         trassi
# 486                  red king crab
# 529                 common octopus
# 561                     irish moss
# 570                 leather chiton
# 588    north pacific giant octopus
# 592                   spotted seal
# 626                   sea cucumber
# 627               steller sea lion
# 628                   bearded seal
# 629                    ringed seal
# 654                          whelk
# 671                  spiny lobster
# 678                       bivalvia
# 680                         walrus
# 690                   purple laver
# 691                         wakame
# 704                      jellyfish
# 733                      true seal
# 734                      red algae
# 735                          kombu
# 908                      ascidians
# 930                          squid
# Name: ingredient, dtype: object
# Fish
# 146                   bonito
# 147                   caviar
# 148                  codfish
# 149                     fish
# 150               fatty fish
# 151                lean fish
# 152                 fish oil
# 153              smoked fish
# 154                   salmon
# 491         atlantic herring
# 492        atlantic mackerel
# 493           painted comber
# 494         atlantic pollock
# 495        atlantic wolffish
# 497             striped bass
# 500             beluga whale
# 503         alaska blackfish
# 504    northern bluefin tuna
# 505                 bluefish
# 507            bowhead whale
# 513                   burbot
# 515      american butterfish
# 522              common carp
# 523          channel catfish
# 527                    cisco
# 528           nuttall cockle
# 534         atlantic croaker
# 535                     cusk
# 536               cuttlefish
# 538                devilfish
#                ...
# 679                 flatfish
# 698             spot croaker
# 701        atlantic menhaden
# 705                  anchovy
# 706             blue whiting
# 707               carp bream
# 709                 sturgeon
# 710                    charr
# 711               common dab
# 712            spiny dogfish
# 714           anguilliformes
# 716                  garfish
# 717               gadiformes
# 719               lake trout
# 720               lemon sole
# 721               lumpsucker
# 722               scombridae
# 723           norway haddock
# 724              norway pout
# 728                pikeperch
# 729           pleuronectidae
# 731      pacific ocean perch
# 737                true sole
# 738                  catfish
# 740              common tuna
# 741                  cetacea
# 743                    conch
# 777       other fish product
# 795                      roe
# 796                cichlidae
# Name: ingredient, Length: 120, dtype: object
# Flower
# 155                artichoke
# 156                 champaca
# 157                  jasmine
# 158                 lavendar
# 159                     rose
# 420                sunflower
# 443                dandelion
# 526    garland chrysanthemum
# 631          sesbania flower
# Name: ingredient, dtype: object
# Fruit
# 160                      apple
# 161                apple sauce
# 162                    apricot
# 163                    avocado
# 164                     babaco
# 165                     banana
# 166                       beli
# 167      byrsonima crassifolia
# 168               cashew apple
# 169                  cherimoya
# 170                    coconut
# 171                    currant
# 172              black currant
# 173                red currant
# 174              white currant
# 175                      dates
# 176                     durian
# 178                     feijoa
# 179                        fig
# 180                      grape
# 181                      guava
# 182                    hogplum
# 183                  jackfruit
# 184                  kiwifruit
# 185                     litchi
# 186                     loquat
# 187                malay apple
# 188                      mango
# 189                      melon
# 190                 musk melon
#                 ...
# 213                    soursop
# 214    spineless monkey orange
# 215                  starfruit
# 216                   tamarind
# 217                  woodapple
# 391                pomegranate
# 395             water chestnut
# 397            garcinia indica
# 415         japanese persimmon
# 427                     medlar
# 453            muscadine grape
# 462                   rambutan
# 473              skunk currant
# 484              winter squash
# 508                 breadfruit
# 517           butternut squash
# 520                 natal plum
# 565                     jujube
# 575               mammee apple
# 576          purple mangosteen
# 595           common persimmon
# 610               malabar plum
# 611                   rose hip
# 727                  persimmon
# 849               horned melon
# 859                    cupuau
# 871                      nance
# 928           japanese pumpkin
# 932            buffalo currant
# 934           japanese pumpkin
# Name: ingredient, Length: 82, dtype: object
# Fruit-Berry
# 177    elderberry
# Name: ingredient, dtype: object
# Fruit Citrus
# 234           bergamot
# 235      citrus fruits
# 236         grapefruit
# 237            kumquat
# 238              lemon
# 239               lime
# 240    mandarin orange
# 241     satsuma orange
# 242          tangerine
# 413            pummelo
# Name: ingredient, dtype: object
# Fruit Essence
# 243    vanilla
# Name: ingredient, dtype: object
# Fungus
# 244            mushroom
# 245             truffle
# 480             abalone
# 688           jew's ear
# 689            shiitake
# 692           enokitake
# 694     oyster mushroom
# 695    cloud ear fungus
# 696             maitake
# 708         chanterelle
# 823           morchella
# Name: ingredient, dtype: object
# Herb
# 246              angelica
# 247             artemisia
# 248                 basil
# 249             buckwheat
# 250               calamus
# 251               chervil
# 252             coriander
# 253              cornmint
# 254                  dill
# 255                fennel
# 256             fenugreek
# 257                garlic
# 258            lemon balm
# 259             liqourice
# 260                  mint
# 261               rhubarb
# 262              rosemary
# 263                  sage
# 264             spearmint
# 265      scotch spearmint
# 266              tarragon
# 267                 thyme
# 348            peppermint
# 382            curry leaf
# 403         silver linden
# 405         lemon verbena
# 408                borage
# 409                capers
# 410             safflower
# 417          rocket salad
# 424          garden cress
# 425       mexican oregano
# 430      evening primrose
# 437                sorrel
# 438         summer savory
# 439         winter savory
# 444                linden
# 448        common verbena
# 472       pineappple sage
# 487               alfalfa
# 488              amaranth
# 524                  chia
# 539                  dock
# 550              fireweed
# 602     american pokeweed
# 612               roselle
# 647                  teff
# 659       tea leaf willow
# 693               epazote
# 699              sourdock
# 703    narrowleaf cattail
# Name: ingredient, dtype: object
# Meat
# 268                  beef
# 269        beef processed
# 270               chicken
# 272                   ham
# 273                  lamb
# 274                  meat
# 275                mutton
# 276                  pork
# 277              sukiyaki
# 278                turkey
# 498                beaver
# 501                 bison
# 502            black bear
# 506             wild boar
# 511            brown bear
# 512               buffalo
# 519               caribou
# 537             mule deer
# 542          mallard duck
# 544                   elk
# 545                   emu
# 553         greylag goose
# 559                 horse
# 580                 moose
# 584               muskrat
# 590               opossum
# 591               ostrich
# 596              pheasant
# 603            polar bear
# 606       european rabbit
# 607               raccoon
# 640                 squab
# 641              squirrel
# 673                  deer
# 676                rabbit
# 677               beefalo
# 684      great horned owl
# 685                 quail
# 713              anatidae
# 715             true frog
# 718         mountain hare
# 730        rock ptarmigan
# 736                 snail
# 742            columbidae
# 769    other meat product
# 799          green turtle
# Name: ingredient, dtype: object
# Dish
# 271    frankfurter sausage
# 746              ice cream
# 749                 nougat
# 750                 toffee
# 751                   cake
# 752                  pizza
# 754       other snack food
# 755                 pastry
# 756                 dragée
# 757            chewing gum
# 758               marzipan
# 759         salad dressing
# 764                sausage
# 765               meatball
# 766                   pate
# 768          meat bouillon
# 779               dumpling
# 780                   soup
# 782              remoulade
# 784              fruit gum
# 794               zwieback
# 798              snack bar
# 801                burrito
# 802              hamburger
# 803                  chili
# 804                   taco
# 805               tortilla
# 806                 nachos
# 807                  salad
# 810               egg roll
#               ...
# 846     breakfast sandwich
# 847                  adobo
# 848    macaroni and cheese
# 850              hushpuppy
# 852                 relish
# 853            fruit salad
# 855        vegetarian food
# 856               cold cut
# 866                    pie
# 868              soy cream
# 869         ice cream cone
# 872                  natto
# 873                ravioli
# 874               scrapple
# 875       other pasta dish
# 876              succotash
# 877                 tamale
# 878              rice cake
# 882                 akutaq
# 898              trail mix
# 905                 pupusa
# 906               empanada
# 907                  arepa
# 909           gefilte fish
# 911            fish burger
# 912             other dish
# 913                pot pie
# 920                 hummus
# 921           potato puffs
# 922          potato gratin
# Name: ingredient, Length: 77, dtype: object
# Nut
# 279               almond
# 280           brazil nut
# 285               peanut
# 290              filbert
# 291             hazelnut
# 292        macadamia nut
# 293                 nuts
# 294               pecans
# 295               walnut
# 406           cashew nut
# 411             chestnut
# 433            pistachio
# 483                acorn
# 499            beech nut
# 516            butternut
# 525     chinese chestnut
# 548    european chestnut
# 552          ginkgo nuts
# 563    japanese chestnut
# 598             pili nut
# 857           mixed nuts
# Name: ingredient, dtype: object
# Seed
# 281           cocoa
# 296      muskmallow
# 297          sesame
# 385        flaxseed
# 389    nigella seed
# Name: ingredient, dtype: object
# Legume
# 282             beans
# 283        lima beans
# 284      kidney beans
# 286              peas
# 287           soybean
# 288       soybean oil
# 398      cluster bean
# 400        pigeon pea
# 412          chickpea
# 422         grass pea
# 423           lentils
# 431            millet
# 432      scarlet bean
# 449       adzuki bean
# 450         gram bean
# 451         mung bean
# 452     climbing bean
# 532       catjang pea
# 560     hyacinth bean
# 581         moth bean
# 660       winged bean
# 672    black-eyed pea
# 683     yardlong bean
# Name: ingredient, dtype: object
# Plant Derivative
# 289          soybean sauce
# 309          fermented tea
# 312               creosote
# 313                  honey
# 314               macaroni
# 315            mustard oil
# 316          peanut butter
# 317             peanut oil
# 319                 storax
# 320                vinegar
# 381    apple cider vinegar
# 509     breadnut tree seed
# 531             cottonseed
# 566                   jute
# 783       chocolate spread
# 786           cocoa butter
# 787           cocoa powder
# 788              chocolate
# 793                   tofu
# 854             soy yogurt
# Name: ingredient, dtype: object
# Plant
# 298                 allium
# 299                alpinia
# 300                ceriman
# 301                chicory
# 302                   hops
# 303                 laurel
# 304                 myrtle
# 305                  olive
# 306                   pine
# 307              sassafras
# 308                    tea
# 310                tobacco
# 311             watercress
# 426                 lupine
# 434               purslane
# 445      small leaf linden
# 459                 longan
# 481                abiyuch
# 496          bamboo shoots
# 514        giant butterbur
# 518                cardoon
# 521                  carob
# 546          oregon yampah
# 569          lambsquarters
# 573           white lupine
# 577      alpine sweetvetch
# 586                  nopal
# 599        colorado pinyon
# 601        french plantain
# 622         common salsify
# 663                 yautia
# 681    alaska wild rhubarb
# 687                  rowal
# 697           ostrich fern
# 702                  agave
# 725               oil palm
# 726              sago palm
# 732          black salsify
# 739                thistle
# 858           babassu palm
# 860              shea tree
# 861      oil-seed camellia
# 862                ucuhuba
# 879              tree fern
# 910       yellow pond lily
# Name: ingredient, dtype: object
# Spice
# 321           anise
# 322    anise hyssop
# 323      star anise
# 324         caraway
# 325        cardamom
# 326          cassia
# 327          celery
# 328        cinnamon
# 329           clove
# 330           cumin
# 331          ginger
# 332            mace
# 333        marjoram
# 334          nutmeg
# 335         oregano
# 336         parsley
# 337          pepper
# 338         saffron
# 339        turmeric
# 373        allspice
# 374      asafoetida
# 379      carom seed
# 386        jalapeno
# 392      poppy seed
# 396    white pepper
# Name: ingredient, dtype: object
# Vegetable
# 340            green beans
# 341                  chive
# 342                 endive
# 343                   leek
# 344                lettuce
# 345                   okra
# 346                  onion
# 347                shallot
# 380                  chard
# 383         drumstick leaf
# 384               eggplant
# 393                spinach
# 404          redskin onion
# 407                burdock
# 460     pepper c. baccatum
# 461     pepper c. chinense
# 465            welsh onion
# 530             corn salad
# 574        malabar spinach
# 585    new zealand spinach
# 811          heart of palm
# 924         green zucchini
# 925        yellow zucchini
# 931              colocasia
# Name: ingredient, dtype: object
# Cabbage
# 349           broccoli
# 350    brussels sprout
# 351            cabbage
# 352        cauliflower
# 353        horseradish
# 354            mustard
# 357           kohlrabi
# 359             wasabi
# 421      swamp cabbage
# 468          komatsuna
# 469           pak choy
# 471            kai lan
# 510             rapini
# 567               kale
# 604     prairie turnip
# 636      hedge mustard
# Name: ingredient, dtype: object
# Vegetable Root
# 355          radish
# 356          turnip
# 358        rutabaga
# 365        beetroot
# 366          carrot
# 367         parsnip
# 368    sweet potato
# 458         ginseng
# Name: ingredient, dtype: object
# Vegetable Fruit
# 360         capsicum
# 361    cherry pepper
# 362           tomato
# 394     turkey berry
# Name: ingredient, dtype: object
# Gourd
# 363        chayote
# 364       cucumber
# 375       ashgourd
# 376    bittergourd
# 377    bottlegourd
# 650    towel gourd
# 700          tinda
# Name: ingredient, dtype: object
# Vegetable Stem
# 369    asparagus
# Name: ingredient, dtype: object
# Vegetable Tuber
# 370                cassava
# 371                 potato
# 489              arrowhead
# 490              arrowroot
# 564    jerusalem artichoke
# 582           mountain yam
# 646                   taro
# 661                    yam
# 662                 jicama
# 836          tapioca pearl
# Name: ingredient, dtype: object
# Additive
# 485                     agar
# 639                spirulina
# 760                    sauce
# 761                     salt
# 763                    sugar
# 767         sugar substitute
# 771                   casein
# 772           fruit preserve
# 773          leavening agent
# 775                  gelatin
# 776                    water
# 781                    syrup
# 792                     miso
# 797                    icing
# 808                  topping
# 817          gelatin dessert
# 825                   pectin
# 841                   spread
# 845                  ketchup
# 864              cooking oil
# 867               shortening
# 870                 molasses
# 914                 stuffing
# 918                margarine
# 919    margarine like spread
# Name: ingredient, dtype: object

# %%
remove_these_list = ['Additive', 'Animal Product', 'Dairy', 'Vegetable Tuber', 'Bakery', 'Beverage Caffeinated', 'Beverage Alcoholic', 'Beverage', 'Cereal', 'Dish', 'Essential Oil', 'Flower', 'Fruit-Berry', 'Gourd', 'Legume', 'Maize', 'Plant', 'Seed', 'Vegetable Stem']
remove_these_list.sort
remove_these_list
# Out:
# ['Additive',
#  'Animal Product',
#  'Dairy',
#  'Vegetable Tuber',
#  'Bakery',
#  'Beverage Caffeinated',
#  'Beverage Alcoholic',
#  'Beverage',
#  'Cereal',
#  'Dish',
#  'Essential Oil',
#  'Flower',
#  'Fruit-Berry',
#  'Gourd',
#  'Legume',
#  'Maize',
#  'Plant',
#  'Seed',
#  'Vegetable Stem']

# %%
list_to_use = ['Berry', 'Cabbage', 'Fish', 'Fruit', 'Fruit Citrus', 'Fruit Essence', 'Fungus', 'Herb', 'Meat', 'Nut', 'Plant Derivative', 'Seafood', 'Spice', 'Vegetable', 'Vegetable Fruit', 'Vegetable Root']
list_to_use.sort
list_to_use
# Out:
# ['Berry',
#  'Cabbage',
#  'Fish',
#  'Fruit',
#  'Fruit Citrus',
#  'Fruit Essence',
#  'Fungus',
#  'Herb',
#  'Meat',
#  'Nut',
#  'Plant Derivative',
#  'Seafood',
#  'Spice',
#  'Vegetable',
#  'Vegetable Fruit',
#  'Vegetable Root']

# %% [markdown]
# # After Removing Ingredients that are in certain categories

# %%
flavorDB_pandas = flavorDB_pandas[flavorDB_pandas["category"].isin(list_to_use)]

# %%
flavorDB_pandas.shape
# Out:
# (516, 9)

# %%
flavorDB_pandas.head()
# Out:
#                           _id category  \
# 127  5ca27ddc13218a1eabac6455    Berry
# 133  5ca27de313218a1eabac645b  Seafood
# 134  5ca27de513218a1eabac645c  Seafood
# 135  5ca27de613218a1eabac645d  Seafood
# 136  5ca27de713218a1eabac645e  Seafood
#
#                                    flavor_of_molecules      ingredient  \
# 127  [[sweet,  new mown hay,  green,  tonka,  bitte...  sea buckthorns
# 133  [[cherry,  caramel,  nut,  phenolic], [apple, ...            clam
# 134  [[coconut,  wax,  fat,  waxy,  fatty,  earthy,...            crab
# 135  [[orange,  waxy,  fresh,  fatty,  floral,  iri...        crayfish
# 136  [[sweet,  new mown hay,  green,  tonka,  bitte...            kelp
#
#                                           molecule_IDs  \
# 127  [323, 107971, 7284, 10448, 7150, 638011, 8468,...
# 133  [14511, 8785, 8193, 8163, 8063, 9862, 7909, 79...
# 134  [8193, 8063, 5281, 7909, 7501, 7519, 8051, 188...
# 135  [8163, 5283321, 7501, 8051, 18635, 7002, 454, ...
# 136  [323, 107971, 7284, 10448, 7150, 638011, 64373...
#
#                                              molecules  \
# 127  [coumarin, Daidzin, 2-Methylbutyraldehyde, 3-m...
# 133  [3-Methyl-2-Cyclohexen-1-One, Benzyl Acetate, ...
# 134  [1-Dodecanol, Pentanal, stearic acid, 4-Methyl...
# 135  [2-Undecanone, trans,trans-2,4-Heptadienal, St...
# 136  [coumarin, Daidzin, 2-Methylbutyraldehyde, 3-m...
#
#                                          set_molecules  \
# 127  {cis-3-Hexenal, quercetin, hydrogen cyanide, V...
# 133  {octanoic acid, 2-Ethylhexan-1-ol, indole, Met...
# 134  {2-Ethylhexan-1-ol, 2-Heptanone, 2-Pentanone, ...
# 135  {2-Heptanone, cis-2-Penten-1-ol, Pyrrole, CID ...
# 136  {cis-3-Hexenal, hydrogen cyanide, 2-Butanone, ...
#
#                                       set_molecules_ID  molecule_quantity
# 127  {637566, 8723, 26447, 13144, 527, 637542, 240,...                113
# 133  {8027, 9862, 798, 8129, 1068, 15394, 1549778, ...                 61
# 134  {798, 8129, 1068, 5281, 18938, 878, 5311110, 7...                 38
# 135  {8027, 31260, 8129, 957, 7501, 6654, 1130, 816...                 32
# 136  {5318599, 637566, 8723, 26447, 13144, 527, 637...                104

# %%
with open('../data/pandas/flavorDB_pandas.pickle', 'wb') as file:
    file.write(pickle.dumps(flavorDB_pandas))
    file.close()

# %%
ingredients_list = flavorDB_pandas["ingredient"].tolist()
ingredients_list.sort()
ingredients_list
# Out:
# ['abalone',
#  'acerola',
#  'acorn',
#  'alaska blackfish',
#  'alaska pollock',
#  'albacore tuna',
#  'alfalfa',
#  'allspice',
#  'almond',
#  'amaranth',
#  'american butterfish',
#  'american pokeweed',
#  'american shad',
#  'anatidae',
#  'anchovy',
#  'angelica',
#  'anguilliformes',
#  'anise',
#  'anise hyssop',
#  'apple',
#  'apple cider vinegar',
#  'apple sauce',
#  'apricot',
#  'artemisia',
#  'asafoetida',
#  'ascidians',
#  'atlantic croaker',
#  'atlantic halibut',
#  'atlantic herring',
#  'atlantic mackerel',
#  'atlantic menhaden',
#  'atlantic pollock',
#  'atlantic salmon',
#  'atlantic wolffish',
#  'avocado',
#  'babaco',
#  'banana',
#  'bartlett pear',
#  'basil',
#  'bayberry',
#  'bearded seal',
#  'beaver',
#  'beech nut',
#  'beef',
#  'beef processed',
#  'beefalo',
#  'beetroot',
#  'beli',
#  'beluga whale',
#  'bergamot',
#  'berry',
#  'bilberry',
#  'bison',
#  'bitter cherry',
#  'bitter orange',
#  'bivalvia',
#  'black bear',
#  'black crowberry',
#  'black currant',
#  'black huckleberry',
#  'black mulberry',
#  'black raspberry',
#  'blackberry',
#  'blue whiting',
#  'blueberry',
#  'bluefish',
#  'bonito',
#  'borage',
#  'bowhead whale',
#  'boysenberry',
#  'brazil nut',
#  'breadfruit',
#  'breadnut tree seed',
#  'broad whitefish',
#  'broccoli',
#  'brown bear',
#  'brussels sprout',
#  'buckwheat',
#  'buffalo',
#  'buffalo currant',
#  'burbot',
#  'burdock',
#  'butternut',
#  'butternut squash',
#  'byrsonima crassifolia',
#  'cabbage',
#  'calamus',
#  'canada blueberry',
#  'capers',
#  'capsicum',
#  'caraway',
#  'cardamom',
#  'caribou',
#  'carom seed',
#  'carp bream',
#  'carrot',
#  'cashew apple',
#  'cashew nut',
#  'cassia',
#  'catfish',
#  'cauliflower',
#  'caviar',
#  'celery',
#  'cetacea',
#  'channel catfish',
#  'chanterelle',
#  'chard',
#  'charr',
#  'cherimoya',
#  'cherry',
#  'cherry pepper',
#  'cherry tomato',
#  'chervil',
#  'chestnut',
#  'chia',
#  'chicken',
#  'chinese bayberry',
#  'chinese chestnut',
#  'chinese quince',
#  'chinook salmon',
#  'chive',
#  'chocolate',
#  'chocolate spread',
#  'chum salmon',
#  'cichlidae',
#  'cinnamon',
#  'cisco',
#  'citrus fruits',
#  'clam',
#  'cloud ear fungus',
#  'cloudberry',
#  'clove',
#  'clupeinae',
#  'cocoa butter',
#  'cocoa powder',
#  'coconut',
#  'codfish',
#  'coho salmon',
#  'colocasia',
#  'columbidae',
#  'common carp',
#  'common dab',
#  'common ling',
#  'common octopus',
#  'common persimmon',
#  'common tuna',
#  'common verbena',
#  'conch',
#  'coriander',
#  'corn salad',
#  'cornmint',
#  'cottonseed',
#  'crab',
#  'cranberry',
#  'crayfish',
#  'creosote',
#  'cumin',
#  'cupua\x8du',
#  'currant',
#  'curry leaf',
#  'cusk',
#  'cuttlefish',
#  'dates',
#  'deer',
#  'deerberry',
#  'devilfish',
#  'dill',
#  'dock',
#  'dolphin fish',
#  'drumstick leaf',
#  'durian',
#  'eggplant',
#  'elk',
#  "elliott's blueberry",
#  'emu',
#  'endive',
#  'enokitake',
#  'epazote',
#  'european anchovy',
#  'european chestnut',
#  'european rabbit',
#  'evening primrose',
#  'fatty fish',
#  'feijoa',
#  'fennel',
#  'fenugreek',
#  'fermented tea',
#  'fig',
#  'filbert',
#  'fireweed',
#  'fish',
#  'fish oil',
#  'flatfish',
#  'florida pompano',
#  'freshwater drum',
#  'freshwater eel',
#  'gadiformes',
#  'garcinia indica',
#  'garden cress',
#  'garfish',
#  'garlic',
#  'ginger',
#  'ginkgo nuts',
#  'ginseng',
#  'gooseberry',
#  'grape',
#  'grapefruit',
#  'great horned owl',
#  'greater sturgeon',
#  'green beans',
#  'green turtle',
#  'green zucchini',
#  'greenland halibut',
#  'greylag goose',
#  'groundcherry',
#  'grouper',
#  'guava',
#  'haddock',
#  'ham',
#  'hazelnut',
#  'heart of palm',
#  'hedge mustard',
#  'hippoglossus',
#  'hogplum',
#  'honey',
#  'horned melon',
#  'horse',
#  'horseradish',
#  'irish moss',
#  'jackfruit',
#  'jalapeno',
#  'japanese chestnut',
#  'japanese persimmon',
#  'japanese pumpkin',
#  'japanese pumpkin',
#  'jellyfish',
#  "jew's ear",
#  'jostaberry',
#  'jujube',
#  'jute',
#  'kai lan',
#  'kale',
#  'kelp',
#  'king mackerel',
#  'kiwifruit',
#  'kohlrabi',
#  'komatsuna',
#  'kombu',
#  'krill',
#  'kumquat',
#  'lake trout',
#  'lamb',
#  'lean fish',
#  'leather chiton',
#  'leek',
#  'lemon',
#  'lemon balm',
#  'lemon sole',
#  'lemon verbena',
#  'lettuce',
#  'lime',
#  'linden',
#  'lingcod',
#  'lingonberry',
#  'liqourice',
#  'litchi',
#  'lobster',
#  'loganberry',
#  'loquat',
#  'lumpsucker',
#  'macadamia nut',
#  'macaroni',
#  'mace',
#  'maitake',
#  'malabar plum',
#  'malabar spinach',
#  'malay apple',
#  'mallard duck',
#  'mammee apple',
#  'mandarin orange',
#  'mango',
#  'marjoram',
#  'meat',
#  'medlar',
#  'melon',
#  'mexican groundcherry',
#  'mexican oregano',
#  'milkfish',
#  'mint',
#  'mixed nuts',
#  'mollusc',
#  'monkfish',
#  'moose',
#  'morchella',
#  'mountain hare',
#  'mountain papaya',
#  'mulberry',
#  'mule deer',
#  'muscadine grape',
#  'mushroom',
#  'musk melon',
#  'muskrat',
#  'mustard',
#  'mustard oil',
#  'mutton',
#  'nance',
#  'nanking cherry',
#  'naranjilla',
#  'narrowleaf cattail',
#  'natal plum',
#  'new zealand spinach',
#  'north pacific giant octopus',
#  'northern bluefin tuna',
#  'northern pike',
#  'norway haddock',
#  'norway pout',
#  'nutmeg',
#  'nuts',
#  'nuttall cockle',
#  'ocean pout',
#  'ohelo berry',
#  'okra',
#  'onion',
#  'opossum',
#  'orange',
#  'orange roughy',
#  'oregano',
#  'ostrich',
#  'other fish product',
#  'other meat product',
#  'oyster',
#  'oyster mushroom',
#  'pacific herring',
#  'pacific jack mackerel',
#  'pacific ocean perch',
#  'pacific rockfish',
#  'pacific sardine',
#  'painted comber',
#  'pak choy',
#  'papaya',
#  'parsley',
#  'parsnip',
#  'passionfruit',
#  'pawpaw',
#  'peach',
#  'peanut',
#  'peanut butter',
#  'peanut oil',
#  'pear',
#  'pecans',
#  'pepino',
#  'pepper',
#  'pepper c. baccatum',
#  'pepper c. chinense',
#  'peppermint',
#  'perciformes',
#  'percoidei',
#  'persimmon',
#  'pheasant',
#  'pikeperch',
#  'pili nut',
#  'pineapple',
#  'pineappple sage',
#  'pink salmon',
#  'pistachio',
#  'pitanga',
#  'pleuronectidae',
#  'plum',
#  'plumcot',
#  'polar bear',
#  'pollock',
#  'pomegranate',
#  'poppy seed',
#  'pork',
#  'prairie turnip',
#  'prawn',
#  'prickly pear',
#  'pummelo',
#  'pumpkin',
#  'pumpkinseed sunfish',
#  'purple laver',
#  'purple mangosteen',
#  'quail',
#  'quince',
#  'rabbit',
#  'raccoon',
#  'radish',
#  'rainbow smelt',
#  'rainbow trout',
#  'raisin',
#  'rambutan',
#  'rapini',
#  'raspberry',
#  'red algae',
#  'red currant',
#  'red king crab',
#  'red raspberry',
#  'redskin onion',
#  'rhubarb',
#  'ringed seal',
#  'rock ptarmigan',
#  'rocket salad',
#  'roe',
#  'rose hip',
#  'roseapple',
#  'roselle',
#  'rosemary',
#  'rowanberry',
#  'rutabaga',
#  'sablefish',
#  'safflower',
#  'saffron',
#  'sage',
#  'salmon',
#  'salmonberry',
#  'salmonidae',
#  'sapodilla',
#  'saskatoon berry',
#  'satsuma orange',
#  'scallop',
#  'scombridae',
#  'scotch spearmint',
#  'scup',
#  'sea buckthorns',
#  'sea cucumber',
#  'sea trout',
#  'shallot',
#  'shark',
#  'sheefish',
#  'sheepshead',
#  'shellfish',
#  'shiitake',
#  'shrimp',
#  'silver linden',
#  'skunk currant',
#  'smelt',
#  'smoked fish',
#  'snail',
#  'snapper',
#  'sockeye salmon',
#  'sorrel',
#  'sour cherry',
#  'sourdock',
#  'soursop',
#  'soy yogurt',
#  'soybean sauce',
#  'spanish mackerel',
#  'sparkleberry',
#  'spearmint',
#  'spinach',
#  'spineless monkey orange',
#  'spiny dogfish',
#  'spiny lobster',
#  'spot croaker',
#  'spotted seal',
#  'squab',
#  'squashberry',
#  'squid',
#  'squirrel',
#  'star anise',
#  'starfruit',
#  'steller sea lion',
#  'storax',
#  'strawberry',
#  'strawberry jam',
#  'striped bass',
#  'striped mullet',
#  'sturgeon',
#  'sukiyaki',
#  'summer savory',
#  'swamp cabbage',
#  'sweet potato',
#  'swordfish',
#  'tamarind',
#  'tangerine',
#  'tarragon',
#  'tea leaf willow',
#  'teff',
#  'thyme',
#  'tilefish',
#  'tofu',
#  'tomato',
#  'trassi',
#  'true frog',
#  'true seal',
#  'true sole',
#  'truffle',
#  'turbot',
#  'turkey',
#  'turkey berry',
#  'turmeric',
#  'turnip',
#  'vanilla',
#  'vinegar',
#  'wakame',
#  'walleye',
#  'walnut',
#  'walrus',
#  'wasabi',
#  'water chestnut',
#  'welsh onion',
#  'whelk',
#  'white currant',
#  'white pepper',
#  'white sucker',
#  'whitefish',
#  'whiting',
#  'wild boar',
#  'wild cherry',
#  'winter savory',
#  'winter squash',
#  'woodapple',
#  'yellow passionfruit',
#  'yellow zucchini',
#  'yellowfin tuna',
#  'yellowtail amberjack']

# %%
with open('../data/ingredients/ingredient_full_list.pickle', 'wb') as file:
    file.write(pickle.dumps(ingredients_list))
    file.close()

# %%
# After Removing Ingredients that have no recipes

# %%
#Opening the pickled file
pickle_in = open("../../../data/ingredients/ingredients_with_recipes.pickle", "rb")

#Getting the dictionary from the pickle
ingredients_with_recipes = pickle.load(pickle_in)

# %%
ingredients_with_recipes
# Out:
# {'acorn',
#  'albacore tuna',
#  'allspice',
#  'almond',
#  'amaranth',
#  'anchovy',
#  'anise',
#  'apple',
#  'apple brandy',
#  'apple cider vinegar',
#  'apricot',
#  'arrowroot',
#  'artichoke',
#  'asparagus',
#  'atlantic salmon',
#  'avocado',
#  'bamboo shoots',
#  'banana',
#  'barley',
#  'bartlett pear',
#  'basil',
#  'basmati rice',
#  'beans',
#  'beef',
#  'beer',
#  'beetroot',
#  'bitter orange',
#  'blackberry',
#  'blackberry brandy',
#  'blue cheese',
#  'bourbon whisky',
#  'brandy',
#  'brazil nut',
#  'buffalo',
#  'bulgur',
#  'butter',
#  'buttermilk',
#  'butternut',
#  'butternut squash',
#  'canola oil',
#  'capers',
#  'cardamom',
#  'carob',
#  'carrot',
#  'cashew nut',
#  'catfish',
#  'caviar',
#  'celery',
#  'champagne',
#  'chayote',
#  'cheddar cheese',
#  'cheese',
#  'cherry',
#  'cherry brandy',
#  'cherry tomato',
#  'chervil',
#  'chicken',
#  'chicory',
#  'chocolate',
#  'chocolate spread',
#  'cider',
#  'cinnamon',
#  'clam',
#  'clary sage',
#  'cocoa',
#  'cocoa butter',
#  'cocoa powder',
#  'coconut',
#  'codfish',
#  'coffee',
#  'condensed milk',
#  'cooking oil',
#  'coriander',
#  'corn',
#  'corn grits',
#  'corn oil',
#  'cornbread',
#  'cottage cheese',
#  'crab',
#  'cream',
#  'cream cheese',
#  'cucumber',
#  'cumin',
#  'currant',
#  'curry leaf',
#  'dates',
#  'dill',
#  'dulce de leche',
#  'egg',
#  'eggplant',
#  'endive',
#  'epazote',
#  'evaporated milk',
#  'fennel',
#  'fenugreek',
#  'feta cheese',
#  'fish',
#  'flaxseed',
#  'flour',
#  'garlic',
#  'gelatin',
#  'ghee',
#  'giant butterbur',
#  'gin',
#  'ginger',
#  'ginkgo nuts',
#  'goat cheese',
#  'goat milk',
#  'grapefruit',
#  'green beans',
#  'green tea',
#  'gruyere cheese',
#  'haddock',
#  'ham',
#  'honey',
#  'icing',
#  'jalapeno',
#  'japanese whisky',
#  'jicama',
#  'kale',
#  'ketchup',
#  'kidney beans',
#  'kiwifruit',
#  'lamb',
#  'leek',
#  'lemon',
#  'lemon balm',
#  'lemon grass',
#  'lemon verbena',
#  'lentils',
#  'lettuce',
#  'lima beans',
#  'lime',
#  'lobster',
#  'macaroni',
#  'madeira wine',
#  'mandarin orange',
#  'mango',
#  'margarine',
#  'marjoram',
#  'meat',
#  'melon',
#  'mexican oregano',
#  'milk',
#  'milk powder',
#  'mint',
#  'miso',
#  'molasses',
#  'monkfish',
#  'mozzarella cheese',
#  'mushroom',
#  'mustard oil',
#  'nutmeg',
#  'nuts',
#  'oats',
#  'okra',
#  'olive',
#  'onion',
#  'orange',
#  'orange oil',
#  'orange roughy',
#  'oregano',
#  'oyster',
#  'oyster mushroom',
#  'papaya',
#  'parmesan cheese',
#  'parsley',
#  'parsnip',
#  'peach',
#  'peanut',
#  'peanut butter',
#  'peanut oil',
#  'pear',
#  'pear brandy',
#  'peas',
#  'pecans',
#  'pepper',
#  'pheasant',
#  'pineapple',
#  'pink salmon',
#  'plum',
#  'plum brandy',
#  'plum wine',
#  'pomegranate',
#  'popcorn',
#  'poppy seed',
#  'pork',
#  'port wine',
#  'potato',
#  'prickly pear',
#  'provolone cheese',
#  'pumpkin',
#  'quail',
#  'quinoa',
#  'rabbit',
#  'raisin',
#  'raspberry',
#  'raspberry brandy',
#  'red rice',
#  'red wine',
#  'rhubarb',
#  'rice',
#  'ricotta cheese',
#  'romano cheese',
#  'roquefort cheese',
#  'rose wine',
#  'rosemary',
#  'rum',
#  'saffron',
#  'sage',
#  'sake',
#  'salmon',
#  'salt',
#  'sauce',
#  'semolina',
#  'sesame',
#  'sherry',
#  'shortening',
#  'shrimp',
#  'skimmed milk',
#  'sockeye salmon',
#  'soursop',
#  'soy yogurt',
#  'soybean oil',
#  'spearmint',
#  'spinach',
#  'squid',
#  'star anise',
#  'strawberry',
#  'strawberry jam',
#  'strawberry wine',
#  'stuffing',
#  'sugar',
#  'sugar substitute',
#  'summer savory',
#  'sweet potato',
#  'sweetcorn',
#  'swiss cheese',
#  'swordfish',
#  'syrup',
#  'tangerine',
#  'tarragon',
#  'tea',
#  'thyme',
#  'tofu',
#  'turkey',
#  'turmeric',
#  'vanilla',
#  'vermouth',
#  'vinegar',
#  'vodka',
#  'walnut',
#  'water',
#  'water chestnut',
#  'watercress',
#  'weinbrand brandy',
#  'wheat',
#  'white pepper',
#  'white wine',
#  'wild rice',
#  'wine',
#  'winter savory',
#  'winter squash',
#  'yam',
#  'yellow zucchini',
#  'yellowfin tuna',
#  'yogurt'}

# %%
ingredients_with_recipes_df = flavorDB_pandas[flavorDB_pandas["ingredient"].isin(ingredients_with_recipes)]

# %%
ingredients_with_recipes_df.head()
# Out:
#                          _id            category  \
# 0   5ca27b8f13218a1eabac63d6      Animal Product
# 9   5ca27b9b13218a1eabac63df  Beverage Alcoholic
# 11  5ca27b9d13218a1eabac63e1  Beverage Alcoholic
# 13  5ca27ba013218a1eabac63e3  Beverage Alcoholic
# 15  5ca27ba313218a1eabac63e5  Beverage Alcoholic
#
#                                   flavor_of_molecules         ingredient  \
# 0   [[faint], [very strong,  mothball,  animal,  f...                egg
# 9   [[caramellic,  spicy], [hop_oil,  apricot,  wh...               beer
# 11  [[fragrant,  bread,  woody,  sweet,  baked,  a...             brandy
# 13  [[fragrant,  bread,  woody,  sweet,  baked,  a...       apple brandy
# 15  [[fragrant,  bread,  woody,  sweet,  baked,  a...  blackberry brandy
#
#                                          molecule_IDs  \
# 0   [6322, 6736, 31252, 7909, 7284, 7501, 9609, 12...
# 9   [5367531, 7795, 20083, 10558, 16617, 12209, 22...
# 11  [7362, 20653, 5364399, 61386, 12327, 7762, 805...
# 13  [7362, 20653, 5364399, 61386, 9862, 7775, 1661...
# 15  [7362, 20653, 5364399, 61386, 12327, 7762, 805...
#
#                                             molecules  \
# 0   [L-arginine, 3-Methylindole, 2,5-Dimethylpyraz...
# 9   [(2E,4E)-Undeca-2,4-dienal, Isoamyl butyrate, ...
# 11  [2-Furaldehyde, 2-Methylhexanoic Acid, Ethyl 2...
# 13  [2-Furaldehyde, 2-Methylhexanoic Acid, Ethyl 2...
# 15  [2-Furaldehyde, 2-Methylhexanoic Acid, Ethyl 2...
#
#                                         set_molecules  \
# 0   {CID 644104, 3-Methylbutanal, 1-Penten-3-Ol, 2...
# 9   {Nerolidol, Ethyl Lactate, resveratrol, Isobut...
# 11  {Ethyl Lactate, 2-Phenylethanol, Hexanoic Acid...
# 13  {Ethyl Lactate, 2-Phenylethanol, Isobutyl buty...
# 15  {Ethyl Lactate, 2-Phenylethanol, Hexanoic Acid...
#
#                                      set_molecules_ID  molecule_quantity
# 0   {1049, 3776, 9609, 9261, 454, 6561, 1068, 6441...                 55
# 9   {5281, 643941, 8468, 6560, 7710, 16255, 528086...                263
# 11  {5363388, 5318042, 1049, 8468, 643820, 6560, 1...                 50
# 13  {5363388, 5281167, 5318042, 1049, 31249, 83036...                 74
# 15  {5363388, 5318042, 1049, 8468, 643820, 6560, 1...                 51

# %%
ingredients_with_recipes_df.shape
# Out:
# (268, 9)

# %%
with open('../../../data/ingredients/ingredient_only_pd.pickle', 'wb') as file:
    file.write(pickle.dumps(ingredients_with_recipes_df))
    file.close()
